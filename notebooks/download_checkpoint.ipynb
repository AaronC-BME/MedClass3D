# %% [markdown]
# # Download a pretrained ResEncL checkpoint
#
# Downloads a checkpoint from Hugging Face into a local directory. Edit the **Parameters** cell, then run all cells.

# %% [markdown]
# ## Parameters

# %%
repo_id = "AnonRes/ResEncL-OpenMind-VoCo"
local_dir = "input/ResEncL-OpenMind-VoCo"

# %% [markdown]
# ## Download

# %%
from huggingface_hub import snapshot_download

snapshot_download(repo_id=repo_id, local_dir=local_dir)
